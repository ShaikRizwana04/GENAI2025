# %%
d={"key":30,"key":20}

# %%
d
# Out:
# {'key': 20}

# %%
type(d)
# Out:
# dict

# %%
d={10:[10,20,30]}

# %%
d
# Out:
# {10: [10, 20, 30]}

# %%
my_dict = {
    "name": "Rizwana",
    "age": 21,
    "location": "Bangalore"
}

# %%
my_dict["name"]
# Out:
# 'Rizwana'

# %%
my_dict
# Out:
# {'name': 'Rizwana', 'age': 21, 'location': 'Bangalore'}

# %%
mixed_dict = {
    "name": "Rizwana",
    101: [80, 85, 90],
    3.14: {"unit": "pi"},
    True: "Active"}

# %%
mixed_dict
# Out:
# {'name': 'Rizwana', 101: [80, 85, 90], 3.14: {'unit': 'pi'}, True: 'Active'}

# %%
mixed_dict[3.14]["unit"]
# Out:
# 'pi'

# %%
employee = {
    "id": 1234,
    "name": "Bhavya",
    "department": {
        "name": "Data Science",
        "location": "chennai",
        "floor": 6
    },
    "is_active": True
}

# %%
employee['department']['location']
# Out:
# 'chennai'

# %%
mixed_dict = {
    "name": "megh",
    101: [80, 85, 90],
    3.14: {"unit": "pi"},
    True: "Active",
    None: 0,
    (1, 2): "tuple_key",
    "details": {
        "age": 30,
        "city": "Bangalore"
    },
    "scores": (95, 87, 78),
    "is_verified": False,
    "height": 5.9
}

# %%
mixed_dict[1]
# Out:
# 'Active'

# %%
temp={
   "lat":33.44,
   "lon":-94.04,
   "timezone":"America/Chicago",
   "timezone_offset":-18000,
   "current":{
      "dt":1684929490,
      "sunrise":1684926645,
      "sunset":1684977332,
      "temp":292.55,
      "feels_like":292.87,
      "pressure":1014,
      "humidity":89,
      "dew_point":290.69,
      "uvi":0.16,
      "clouds":53,
      "visibility":10000,
      "wind_speed":3.13,
      "wind_deg":93,
      "wind_gust":6.71,
      "weather":[
         {
            "id":803,
            "main":"Clouds",
            "description":"broken clouds",
            "icon":"04d"
         }
      ]
   } }

# %%
temp['current']['weather'][0]['description'].upper()
# Out:
# 'BROKEN CLOUDS'

# %%
d = {
    "name": "Likki",
    "age": 25,
    "location": "Bangalore"
}

# %%
d.values()
# Out:
# dict_values(['Alice', 25, 'Bangalore'])

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'location'])

# %%
d.items()
# Out:
# dict_items([('name', 'Likki'), ('age', 25), ('location', 'Bangalore')])

# %%
d
# Out:
# {'name': 'Likki', 'age': 25, 'location': 'Bangalore'}

# %%
d.get("age")
# Out:
# 25

# %%
d['name']
# Out:
# 'Likki'

# %%
d
# Out:
# {'name': 'Likki', 'age': 25, 'location': 'Bangalore'}

# %%
d.update({"name":"vidya"})

# %%
d
# Out:
# {'name': 'vidya', 'age': 25, 'location': 'Bangalore'}

# %%
d
# Out:
# {'name': 'vidya', 'age': 25, 'location': 'Bangalore'}

# %%
d
# Out:
# {'name': 'vidya', 'location': 'Bangalore'}

# %%
d.items()
# Out:
# dict_items([('name', 'vidya'), ('location', 'Bangalore')])

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
del d

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-e983f374794d> in <cell line: 0>()
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
d = {
    "name": "Rizu",
    "age": 21,
    "location": "Bangalore"
}

# %%
d
# Out:
# {}

# %%
d.popitem()
# Out:
# ('location', 'Bangalore')

# %%
d
# Out:
# {'name': 'Rizu', 'age': 21}

# %%
isinstance(d,dict)
# Out:
# True

# %%
d
# Out:
# {'name': 'Rizu', 'age': 21}

# %%
isinstance(d['age'],int)
# Out:
# True

# %%
x=[1,2,3,4]

# %%
y=(1,2,3,4)

# %%
x[1]=33
x
# Out:
# [1, 33, 3, 4]

# %%
y=(1,2,2,3,3,4,7)
y.count(2)
# Out:
# 2

# %%
y=(2,3,4,5,1,1,1,2,3,4)
y.index(2)
# Out:
# 0

# %%
x={11,2,32,41,15,6,2,2}

# %%
x
# Out:
# {2, 6, 11, 15, 32, 41}

# %%
x.add(240)

# %%
x
# Out:
# {2, 6, 11, 15, 32, 41, 240}

# %%
y=frozenset([11,2,3,1,2,20,40])

# %%
y
# Out:
# frozenset({1, 2, 3, 11, 20, 40})

# %%
y.add(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-6c9919cbc5b4> in <cell line: 0>()
# ----> 1 y.add(20)
#
# AttributeError: 'frozenset' object has no attribute 'add'
